# %%
import seaborn as sb
import pandas as pd
import matplotlib as mp

# %%
df1 = pd.DataFrame({"Days": [1, 2, 5, 6, 9], "People": [15, 25, 34, 47, 69]})

sb.lineplot(x="Days",y="People",data=df1)
# Out:
# <Axes: xlabel='Days', ylabel='People'>

# %%
df2 = pd.read_csv("/content/drive/MyDrive/Dataset/tips.csv")
sb.lineplot(x="day",y="tip",data=df2,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sb.barplot(x='Days',y='People',data=df1,palette='bright')
# Out:
# <ipython-input-27-c77c0bcd7dc9>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x='Days',y='People',data=df1,palette='bright')
# <Axes: xlabel='Days', ylabel='People'>

# %%
sb.barplot(x="sex",y="tip",data=df2,palette="muted")
# Out:
# <ipython-input-36-d48be3f8cbf8>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x="sex",y="tip",data=df2,palette="muted")
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sb.boxplot(x='sex',y='tip',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sb.violinplot(x='total_bill',y='sex',data=df2)
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sb.displot(df['tip'], kde = True)

# %%
sb.scatterplot(x='total_bill',y='tip',data=df2)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
